# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient("mongodb://root:rootpass@mongo:27017")

# %%
db = client["loja"]
produtos = db["produtos"]

# %%
produtos.insert_many([
{"nome":"Mouse Logitech","categoria":"Informática","preco":120,"estoque":50,"avaliacoes":[4,4,5],"disponivel":True},
{"nome":"Teclado Mecânico","categoria":"Informática","preco":350,"estoque":20,"avaliacoes":[5,5,4],"disponivel":True},
{"nome":"Smartphone Samsung","categoria":"Celulares","preco":2200,"estoque":15,"avaliacoes":[5,4,4],"disponivel":True},
{"nome":"Smartphone Xiaomi","categoria":"Celulares","preco":1800,"estoque":0,"avaliacoes":[4,4,4],"disponivel":False},
{"nome":"Fone Bluetooth","categoria":"Acessórios","preco":250,"estoque":30,"avaliacoes":[4,3,4],"disponivel":True},
{"nome":"Monitor LG","categoria":"Informática","preco":1200,"estoque":8,"avaliacoes":[5,5,5],"disponivel":True},
{"nome":"Carregador USB-C","categoria":"Acessórios","preco":80,"estoque":40,"avaliacoes":[4,4,3],"disponivel":True},
{"nome":"Tablet Lenovo","categoria":"Tablets","preco":1500,"estoque":5,"avaliacoes":[4,5,4],"disponivel":True},
{"nome":"Smartwatch Xiaomi","categoria":"Wearables","preco":900,"estoque":12,"avaliacoes":[4,4,5],"disponivel":True}
])
# Out:
# InsertManyResult([ObjectId('69b3633ba19c2c197636411d'), ObjectId('69b3633ba19c2c197636411e'), ObjectId('69b3633ba19c2c197636411f'), ObjectId('69b3633ba19c2c1976364120'), ObjectId('69b3633ba19c2c1976364121'), ObjectId('69b3633ba19c2c1976364122'), ObjectId('69b3633ba19c2c1976364123'), ObjectId('69b3633ba19c2c1976364124'), ObjectId('69b3633ba19c2c1976364125')], acknowledged=True)

# %%
for item in produtos.find({"preco" : {"$gt" : 500}}):
    print(item)
# Out:
# {'_id': ObjectId('69b3633ba19c2c197636411f'), 'nome': 'Smartphone Samsung', 'categoria': 'Celulares', 'preco': 2200, 'estoque': 15, 'avaliacoes': [5, 4, 4], 'disponivel': True}
# {'_id': ObjectId('69b3633ba19c2c1976364120'), 'nome': 'Smartphone Xiaomi', 'categoria': 'Celulares', 'preco': 1800, 'estoque': 0, 'avaliacoes': [4, 4, 4], 'disponivel': False}
# {'_id': ObjectId('69b3633ba19c2c1976364122'), 'nome': 'Monitor LG', 'categoria': 'Informática', 'preco': 1200, 'estoque': 8, 'avaliacoes': [5, 5, 5], 'disponivel': True}
# {'_id': ObjectId('69b3633ba19c2c1976364124'), 'nome': 'Tablet Lenovo', 'categoria': 'Tablets', 'preco': 1500, 'estoque': 5, 'avaliacoes': [4, 5, 4], 'disponivel': True}
# {'_id': ObjectId('69b3633ba19c2c1976364125'), 'nome': 'Smartwatch Xiaomi', 'categoria': 'Wearables', 'preco': 900, 'estoque': 12, 'avaliacoes': [4, 4, 5], 'disponivel': True}

# %%
dados = list(produtos.find())
dados
# Out:
# [{'_id': ObjectId('69b3633ba19c2c197636411d'),
#   'nome': 'Mouse Logitech',
#   'categoria': 'Informática',
#   'preco': 120,
#   'estoque': 50,
#   'avaliacoes': [4, 4, 5],
#   'disponivel': True},
#  {'_id': ObjectId('69b3633ba19c2c197636411e'),
#   'nome': 'Teclado Mecânico',
#   'categoria': 'Informática',
#   'preco': 350,
#   'estoque': 20,
#   'avaliacoes': [5, 5, 4],
#   'disponivel': True},
#  {'_id': ObjectId('69b3633ba19c2c197636411f'),
#   'nome': 'Smartphone Samsung',
#   'categoria': 'Celulares',
#   'preco': 2200,
#   'estoque': 15,
#   'avaliacoes': [5, 4, 4],
#   'disponivel': True},
#  {'_id': ObjectId('69b3633ba19c2c1976364120'),
#   'nome': 'Smartphone Xiaomi',
#   'categoria': 'Celulares',
#   'preco': 1800,
#   'estoque': 0,
#   'avaliacoes': [4, 4, 4],
#   'disponivel': False},
#  {'_id': ObjectId('69b3633ba19c2c1976364121'),
#   'nome': 'Fone Bluetooth',
#   'categoria': 'Acessórios',
#   'preco': 250,
#   'estoque': 30,
#   'avaliacoes': [4, 3, 4],
#   'disponivel': True},
#  {'_id': ObjectId('69b3633ba19c2c1976364122'),
#   'nome': 'Monitor LG',
#   'categoria': 'Informática',
#   'preco': 1200,
#   'estoque': 8,
#   'avaliacoes': [5, 5, 5],
#   'disponivel': True},
#  {'_id': ObjectId('69b3633ba19c2c1976364123'),
#   'nome': 'Carregador USB-C',
#   'categoria': 'Acessórios',
#   'preco': 80,
#   'estoque': 40,
#   'avaliacoes': [4, 4, 3],
#   'disponivel': True},
#  {'_id': ObjectId('69b3633ba19c2c1976364124'),
#   'nome': 'Tablet Lenovo',
#   'categoria': 'Tablets',
#   'preco': 1500,
#   'estoque': 5,
#   'avaliacoes': [4, 5, 4],
#   'disponivel': True},
#  {'_id': ObjectId('69b3633ba19c2c1976364125'),
#   'nome': 'Smartwatch Xiaomi',
#   'categoria': 'Wearables',
#   'preco': 900,
#   'estoque': 12,
#   'avaliacoes': [4, 4, 5],
#   'disponivel': True}]

# %%
df_produtos = pd.DataFrame(dados)
df_produtos.head()
# Out:
#                         _id                nome    categoria  preco  estoque  \
# 0  69b3633ba19c2c197636411d      Mouse Logitech  Informática    120       50
# 1  69b3633ba19c2c197636411e    Teclado Mecânico  Informática    350       20
# 2  69b3633ba19c2c197636411f  Smartphone Samsung    Celulares   2200       15
# 3  69b3633ba19c2c1976364120   Smartphone Xiaomi    Celulares   1800        0
# 4  69b3633ba19c2c1976364121      Fone Bluetooth   Acessórios    250       30
#
#   avaliacoes  disponivel
# 0  [4, 4, 5]        True
# 1  [5, 5, 4]        True
# 2  [5, 4, 4]        True
# 3  [4, 4, 4]       False
# 4  [4, 3, 4]        True

# %%
df_produtos = df_produtos.drop(columns=["_id"])
df_produtos.head(3)
# Out:
#                  nome    categoria  preco  estoque avaliacoes  disponivel
# 0      Mouse Logitech  Informática    120       50  [4, 4, 5]        True
# 1    Teclado Mecânico  Informática    350       20  [5, 5, 4]        True
# 2  Smartphone Samsung    Celulares   2200       15  [5, 4, 4]        True

# %%
df_produtos["media_avaliacoes"] = df_produtos["avaliacoes"].apply(lambda x : sum(x)/len(x))
df_produtos.head(3)
# Out:
#                  nome    categoria  preco  estoque avaliacoes  disponivel  \
# 0      Mouse Logitech  Informática    120       50  [4, 4, 5]        True
# 1    Teclado Mecânico  Informática    350       20  [5, 5, 4]        True
# 2  Smartphone Samsung    Celulares   2200       15  [5, 4, 4]        True
#
#    media_avaliacoes
# 0          4.333333
# 1          4.666667
# 2          4.333333

# %%
produtos_p = db["produtos_processados"]

# %%
dados_p = df_produtos.to_dict("records")
dados_p
# Out:
# [{'nome': 'Mouse Logitech',
#   'categoria': 'Informática',
#   'preco': 120,
#   'estoque': 50,
#   'avaliacoes': [4, 4, 5],
#   'disponivel': True,
#   'media_avaliacoes': 4.333333333333333},
#  {'nome': 'Teclado Mecânico',
#   'categoria': 'Informática',
#   'preco': 350,
#   'estoque': 20,
#   'avaliacoes': [5, 5, 4],
#   'disponivel': True,
#   'media_avaliacoes': 4.666666666666667},
#  {'nome': 'Smartphone Samsung',
#   'categoria': 'Celulares',
#   'preco': 2200,
#   'estoque': 15,
#   'avaliacoes': [5, 4, 4],
#   'disponivel': True,
#   'media_avaliacoes': 4.333333333333333},
#  {'nome': 'Smartphone Xiaomi',
#   'categoria': 'Celulares',
#   'preco': 1800,
#   'estoque': 0,
#   'avaliacoes': [4, 4, 4],
#   'disponivel': False,
#   'media_avaliacoes': 4.0},
#  {'nome': 'Fone Bluetooth',
#   'categoria': 'Acessórios',
#   'preco': 250,
#   'estoque': 30,
#   'avaliacoes': [4, 3, 4],
#   'disponivel': True,
#   'media_avaliacoes': 3.6666666666666665},
#  {'nome': 'Monitor LG',
#   'categoria': 'Informática',
#   'preco': 1200,
#   'estoque': 8,
#   'avaliacoes': [5, 5, 5],
#   'disponivel': True,
#   'media_avaliacoes': 5.0},
#  {'nome': 'Carregador USB-C',
#   'categoria': 'Acessórios',
#   'preco': 80,
#   'estoque': 40,
#   'avaliacoes': [4, 4, 3],
#   'disponivel': True,
#   'media_avaliacoes': 3.6666666666666665},
#  {'nome': 'Tablet Lenovo',
#   'categoria': 'Tablets',
#   'preco': 1500,
#   'estoque': 5,
#   'avaliacoes': [4, 5, 4],
#   'disponivel': True,
#   'media_avaliacoes': 4.333333333333333},
#  {'nome': 'Smartwatch Xiaomi',
#   'categoria': 'Wearables',
#   'preco': 900,
#   'estoque': 12,
#   'avaliacoes': [4, 4, 5],
#   'disponivel': True,
#   'media_avaliacoes': 4.333333333333333}]

# %%
produtos_p.insert_many(dados_p)
# Out:
# InsertManyResult([ObjectId('69b36ad9a19c2c1976364126'), ObjectId('69b36ad9a19c2c1976364127'), ObjectId('69b36ad9a19c2c1976364128'), ObjectId('69b36ad9a19c2c1976364129'), ObjectId('69b36ad9a19c2c197636412a'), ObjectId('69b36ad9a19c2c197636412b'), ObjectId('69b36ad9a19c2c197636412c'), ObjectId('69b36ad9a19c2c197636412d'), ObjectId('69b36ad9a19c2c197636412e')], acknowledged=True)

# %%
for item in produtos_p.find():
    print(item)
# Out:
# {'_id': ObjectId('69b36ad9a19c2c1976364126'), 'nome': 'Mouse Logitech', 'categoria': 'Informática', 'preco': 120, 'estoque': 50, 'avaliacoes': [4, 4, 5], 'disponivel': True, 'media_avaliacoes': 4.333333333333333}
# {'_id': ObjectId('69b36ad9a19c2c1976364127'), 'nome': 'Teclado Mecânico', 'categoria': 'Informática', 'preco': 350, 'estoque': 20, 'avaliacoes': [5, 5, 4], 'disponivel': True, 'media_avaliacoes': 4.666666666666667}
# {'_id': ObjectId('69b36ad9a19c2c1976364128'), 'nome': 'Smartphone Samsung', 'categoria': 'Celulares', 'preco': 2200, 'estoque': 15, 'avaliacoes': [5, 4, 4], 'disponivel': True, 'media_avaliacoes': 4.333333333333333}
# {'_id': ObjectId('69b36ad9a19c2c1976364129'), 'nome': 'Smartphone Xiaomi', 'categoria': 'Celulares', 'preco': 1800, 'estoque': 0, 'avaliacoes': [4, 4, 4], 'disponivel': False, 'media_avaliacoes': 4.0}
# {'_id': ObjectId('69b36ad9a19c2c197636412a'), 'nome': 'Fone Bluetooth', 'categoria': 'Acessórios', 'preco': 250, 'estoque': 30, 'avaliacoes': [4, 3, 4], 'disponivel': True, 'media_avaliacoes': 3.6666666666666665}
# {'_id': ObjectId('69b36ad9a19c2c197636412b'), 'nome': 'Monitor LG', 'categoria': 'Informática', 'preco': 1200, 'estoque': 8, 'avaliacoes': [5, 5, 5], 'disponivel': True, 'media_avaliacoes': 5.0}
# {'_id': ObjectId('69b36ad9a19c2c197636412c'), 'nome': 'Carregador USB-C', 'categoria': 'Acessórios', 'preco': 80, 'estoque': 40, 'avaliacoes': [4, 4, 3], 'disponivel': True, 'media_avaliacoes': 3.6666666666666665}
# {'_id': ObjectId('69b36ad9a19c2c197636412d'), 'nome': 'Tablet Lenovo', 'categoria': 'Tablets', 'preco': 1500, 'estoque': 5, 'avaliacoes': [4, 5, 4], 'disponivel': True, 'media_avaliacoes': 4.333333333333333}
# {'_id': ObjectId('69b36ad9a19c2c197636412e'), 'nome': 'Smartwatch Xiaomi', 'categoria': 'Wearables', 'preco': 900, 'estoque': 12, 'avaliacoes': [4, 4, 5], 'disponivel': True, 'media_avaliacoes': 4.333333333333333}
